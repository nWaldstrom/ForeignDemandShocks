# %%
import os
import sys
sys.path.append("..")
import numpy as np
import matplotlib.pyplot as plt   
plt.style.use('seaborn-whitegrid')
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
from ForeignEcon.ForeignEcon import NKModelClass
import utils

# %%
model = NKModelClass(name='baseline')
model.find_ss(do_print=True)

# %%
model.compute_jacs(do_print=True,skip_shocks=True,skip_hh=True)
utils.Create_shock('ZF', model, 0.01, absval=False)
model.transition_path(do_print=True)
model.show_IRFs(['C_s','piF_s', 'rF_s'],T_max=40,do_shocks=False,do_targets=False, abs_diff=['piF_s'])
# Out:
# full Jacobians:
# full Jacobian to unknowns computed in 8.4 secs [in evaluate_path(): 8.2 secs]
# finding the transition path:
#  it =   0 -> max. abs. error = 8.02e-04
#    8.02e-04 in NKPC_res
#    0.00e+00 in Euler
#    0.00e+00 in Taylor_res
#  it =   1 -> max. abs. error = 7.24e-06
#    7.24e-06 in NKPC_res
#    4.63e-06 in Euler
#    9.11e-18 in Taylor_res
#  it =   2 -> max. abs. error = 6.33e-08
#    3.68e-09 in NKPC_res
#    6.33e-08 in Euler
#    8.67e-19 in Taylor_res
#  it =   3 -> max. abs. error = 4.94e-10
#    1.28e-10 in NKPC_res
#    4.94e-10 in Euler
#    8.67e-19 in Taylor_res
#
# transition path found in 0.1 secs
# ### varnames ###
